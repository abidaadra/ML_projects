# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'Bedrooms': [3, 4, 2, 5],
    'Bathrooms': [2, 3, 1, 4],
    'House Size (sq ft)': [1800, 2200, 1200, 3000],
    'Crime Rate': [0.05, 0.02, 0.08, 0.03],
    'Price ($)': [250000, 320000, 180000, 450000]
}

# Create a DataFrame from the dictionary
training_data = pd.DataFrame(data)

# Display the training data
print(training_data)
# Out:
#    Bedrooms  Bathrooms  House Size (sq ft)  Crime Rate  Price ($)
# 0         3          2                1800        0.05     250000
# 1         4          3                2200        0.02     320000
# 2         2          1                1200        0.08     180000
# 3         5          4                3000        0.03     450000

# %%
import pandas as pd

# Example testing data
testing_data = pd.DataFrame({
    'Bedrooms': [2, 3, 4],
    'Bathrooms': [1, 2, 3],
    'House Size (sq ft)': [1500, 2000, 2500],
    'Crime Rate': [0.06, 0.04, 0.03],
    'Price ($)': [200000, 280000, 350000]
})

# Display the testing data
print(testing_data)
# Out:
#    Bedrooms  Bathrooms  House Size (sq ft)  Crime Rate  Price ($)
# 0         2          1                1500        0.06     200000
# 1         3          2                2000        0.04     280000
# 2         4          3                2500        0.03     350000

# %%
from sklearn.tree import DecisionTreeRegressor

import numpy as np

# Assuming you have imported necessary libraries and loaded your data

# Fit the model using training_data
regression_model.fit(training_data.iloc[:, :-1], training_data.iloc[:, -1])

# Now you can make predictions using testing_data
predicted = regression_model.predict(testing_data.iloc[:, :-1])

# Calculate RMSE or any other evaluation metric
RMSE = np.sqrt(np.sum(((testing_data.iloc[:, -1] - predicted) ** 2) / len(testing_data.iloc[:, -1])))
RMSE
# Out:
# 65574.38524302
